# %%
# importing gluonTS utilities and pandas
from numpy.random import seed

from gluonts.dataset import common
from gluonts.model import deepar
from gluonts.model import seq2seq
from gluonts.model import n_beats
from gluonts.model import canonical
from gluonts.model import deep_factor
from gluonts.model import wavenet
from gluonts.evaluation import Evaluator
from gluonts.trainer import Trainer
from gluonts.evaluation.backtest import make_evaluation_predictions
from itertools import islice

import pandas as pd
import matplotlib.pyplot as plt
import numpy
# Out:
# <ipython-input-1-6054976ef926>:12: DeprecationWarning: gluonts.trainer is deprecated. Use gluonts.mx.trainer instead.
#   from gluonts.trainer import Trainer

# %%
#Model comparsion under S5ENRS
x1=numpy.loadtxt('deepare5MASE.txt')
x2=numpy.loadtxt('statee5MASE.txt')
x3=numpy.loadtxt('wavnete5MASE.txt')
x4=numpy.loadtxt('DEEPfactor_S5ENRS.txt')
x5=numpy.loadtxt('GP_single_S5ENRS.txt')
x6=numpy.loadtxt('NBEATS_S5ENRS.txt')

# %%
#Plot the boxplot
plt.figure(figsize=(10,5))
plt.title('MASE COMPARISON',fontsize=20)

labels='DeepAR','DeepState','Wavenet','DeepFactor','GP','NBEATS'
plt.boxplot([x1,x2,x3,x4,x5,x6],labels=labels)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f95baf15e0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1f95bb83670>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1f95baf16a0>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x1f95bb83070>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x1f95bb83580>,
# ...
#  'means': []}

# %%
#Output the mean and median of MASE
print(numpy.mean(x1))
print(numpy.mean(x2))
print(numpy.mean(x3))
print(numpy.mean(x4))
print(numpy.mean(x5))
print(numpy.mean(x6))
print(numpy.median(x1))
print(numpy.median(x2))
print(numpy.median(x3))
print(numpy.median(x4))
print(numpy.median(x5))
print(numpy.median(x6))
# Out:
# 3.698083132742976
# 5.7289214410192555
# 27.779352090009482
# 10.80586010564363
# 5.096957451119534
# 3.363847429901127
# 3.1817565516265667
# 5.364745093965034
# 28.732366047870656
# 10.032421728787556
# 5.183286602881263
# 3.236343887201344

# %%
#Model comparsion under NDDUJN
x1=numpy.loadtxt('MASE.txt')
x2=numpy.loadtxt('stateMASE.txt')
x3=numpy.loadtxt('wavnetMASE.txt')
x4=numpy.loadtxt('DEEPfactor_NDDUJN.txt')
x5=numpy.loadtxt('GP_single_NDDUJN.txt')
x6=numpy.loadtxt('NBEATS_NDDUJN.txt')

# %%
#Plot the boxplot of MASE
plt.figure(figsize=(10,5))
plt.title('MASE COMPARISON',fontsize=20)

labels='DeepAR','DeepState','Wavenet','DeepFactor','GP','NBEATS'
plt.boxplot([x1,x2,x3,x4,x5,x6],labels=labels)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f958f343a0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1f9591a2e20>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1f958f34b50>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x1f95c5f5520>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x1f95c5f5880>,
# ...
#  'means': []}

# %%
#Output mean and median
print(numpy.mean(x1))
print(numpy.mean(x2))
print(numpy.mean(x3))
print(numpy.mean(x4))
print(numpy.mean(x5))
print(numpy.mean(x6))
print(numpy.median(x1))
print(numpy.median(x2))
print(numpy.median(x3))
print(numpy.median(x4))
print(numpy.median(x5))
print(numpy.median(x6))
# Out:
# 3.878170834842458
# 3.7265418588478894
# 3.9530405246229536
# 54.15138463448023
# 4.793850719882657
# 3.8413480909475894
# 3.0400457970419037
# 3.5827672229500562
# 3.2106224061542434
# 43.691336469109174
# 4.432548958331931
# 3.41978841152424

# %%
#Model comparsion under RU10GRTR
x1=numpy.loadtxt('deeparruMASE.txt')
x2=numpy.loadtxt('stateruMASE.txt')
x3=numpy.loadtxt('wavnetruMASE.txt')
x4=numpy.loadtxt('DEEPfactor_RU10GRTR.txt')
x5=numpy.loadtxt('GP_single_RU10GRTR.txt')
x6=numpy.loadtxt('NBEATS_RU10GRTR.txt')

# %%
#Plot the boxplot of MASE
plt.figure(figsize=(10,5))
plt.title('MASE COMPARISON',fontsize=20)

labels='DeepAR','DeepState','Wavenet','DeepFactor','GP','NBEATS'
plt.boxplot([x1,x2,x3,x4,x5,x6],labels=labels)

# %%
plt.figure(figsize=(10,5))
plt.title('MASE COMPARISON',fontsize=20)

labels='DeepAR','DeepState','GP','NBEATS'
plt.boxplot([x1,x2,x5,x6],labels=labels)

# %%
#Influence of adding TS: DeepAR
x1=numpy.loadtxt('MASE.txt')
x2=numpy.loadtxt('MASE2.txt')
x3=numpy.loadtxt('MASE3.txt')
x4=numpy.loadtxt('MASE4.txt')
x5=numpy.loadtxt('MASE5.txt')
x6=numpy.loadtxt('MASE6.txt')
x7=numpy.loadtxt('MASE7.txt')
x8=numpy.loadtxt('MASE8.txt')
x9=numpy.loadtxt('MASE9.txt')
x10=numpy.loadtxt('MASE10.txt')

# %%
#Boxplot of MASE
plt.figure(figsize=(16,8))
plt.title('MASE COMPARISON',fontsize=20)

labels='Oringinal','NDDUE15X','NDDUNA','NDDUPXJ','NDDUUK','NDDUWXUS','RU10GRTR','RU20GRTR','S5COND','S5ENRS'
plt.boxplot([x1,x2,x3,x4,x5,x6,x7,x8,x9,x10],labels=labels)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2ca810d3eb0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2ca9d8e77f0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2ca810c18b0>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x2ca9d8e7e50>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x2ca9d2701c0>,
# ...
#  'means': []}

# %%
numpy.median(x10)

# %%
x1=numpy.loadtxt('stateMASE.txt')
x2=numpy.loadtxt('stateMASE2.txt')
x3=numpy.loadtxt('stateMASE3.txt')
x4=numpy.loadtxt('stateMASE4.txt')
x5=numpy.loadtxt('stateMASE5.txt')
x6=numpy.loadtxt('stateMASE6.txt')
x7=numpy.loadtxt('stateMASE7.txt')
x8=numpy.loadtxt('stateMASE8.txt')
x9=numpy.loadtxt('stateMASE9.txt')
x10=numpy.loadtxt('stateMASE10.txt')

# %%
plt.figure(figsize=(16,8))
plt.title('MASE COMPARISON',fontsize=20)

labels='Oringinal','NDDUE15X','NDDUNA','NDDUPXJ','NDDUUK','NDDUWXUS','RU10GRTR','RU20GRTR','S5COND','S5ENRS'
plt.boxplot([x1,x2,x3,x4,x5,x6,x7,x8,x9,x10],labels=labels)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2ca9d102580>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2ca9d102c40>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2ca9d102220>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x2ca9d110340>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x2ca9d1106a0>,
# ...
#  'means': []}

# %%
plt.figure(figsize=(12,6))
plt.title('MASE COMPARISON',fontsize=20)

labels='Oringinal','NDDUE15X','NDDUNA','NDDUPXJ','NDDUUK','NDDUWXUS'
plt.boxplot([x1,x2,x3,x4,x5,x6],labels=labels)

# %%
#Adding feature DeepAR
x1=numpy.loadtxt('NDDUNA-NO.txt')
x2=numpy.loadtxt('NDDUNA1VOLUME.txt')
x3=numpy.loadtxt('NDDUNA1SMAVG.txt')
x4=numpy.loadtxt('NDDUNA1VOLUMESMAVG.txt')

# %%
x1=numpy.loadtxt('NDDUPXJ-NO.txt')
x2=numpy.loadtxt('NDDUPXJ1VOLUME.txt')
x3=numpy.loadtxt('NDDUPXJ1SMAVG.txt')
x4=numpy.loadtxt('NDDUPXJ1VOLUMESMAVG.txt')

# %%
x1=numpy.loadtxt('RU20GRTR-NO.txt')
x2=numpy.loadtxt('RU20GRTR1VOLUME.txt')
x3=numpy.loadtxt('RU20GRTR1SMAVG.txt')
x4=numpy.loadtxt('RU20GRTR1VOLUMESMAVG.txt')

# %%
#Adding feature DeepState
x1=numpy.loadtxt('DEEPSTATE_NDDUNA_price.txt')
x2=numpy.loadtxt('DEEPSTATE_NDDUNA_priceandvolume.txt')
x3=numpy.loadtxt('DEEPSTATE_NDDUNA_smavg.txt')
x4=numpy.loadtxt('DEEPSTATE_NDDUNA_all.txt')

# %%
x1=numpy.loadtxt('DEEPSTATE_NDDUPXJ_price.txt')
x2=numpy.loadtxt('DEEPSTATE_NDDUPXJ_priceandvolume.txt')
x3=numpy.loadtxt('DEEPSTATE_NDDUPXJ_smavg.txt')
x4=numpy.loadtxt('DEEPSTATE_NDDUPXJ_all.txt')

# %%
x1=numpy.loadtxt('DEEPSTATE_RU20GRTR_price.txt')
x2=numpy.loadtxt('DEEPSTATE_RU20GRTR_priceandvolume.txt')
x3=numpy.loadtxt('DEEPSTATE_RU20GRTR_smavg.txt')
x4=numpy.loadtxt('DEEPSTATE_RU20GRTR_all.txt')

# %%
plt.figure(figsize=(8,8))
plt.title('MASE COMPARISON',fontsize=20)

labels='No Feature','Add Volume','Add SMAVG(15)','Add Volume&SMAVG(15)'
plt.boxplot([x1,x2,x3,x4],labels=labels)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f9961fc820>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1f995e5a430>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1f9961fcc70>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x1f995e5ab20>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x1f995e5a640>,
# ...
#  'means': []}

# %%
print(numpy.mean(x1))
print(numpy.mean(x2))
print(numpy.mean(x3))
print(numpy.mean(x4))
print(numpy.median(x1))
print(numpy.median(x2))
print(numpy.median(x3))
print(numpy.median(x4))
# Out:
# 1.8030975829360743
# 2.087882572242526
# 9.57240309707663
# 2.088623485786697
# 1.8216644503010415
# 2.080374499193111
# 6.471097916527949
# 2.083049170141563
